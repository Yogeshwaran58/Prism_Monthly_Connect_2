# %%
# !python --version
# Out:
# Python 3.7.16

# %%
# !git clone https://github.com/NVlabs/stylegan2-ada-pytorch.git
# Out:
# Cloning into 'stylegan2-ada-pytorch'...

# %%
print(torch.cuda.is_available())
print(torch.backends.cudnn.enabled)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_41104\4105612223.py in <module>
# ----> 1 print(torch.cuda.is_available())
#       2 print(torch.backends.cudnn.enabled)
#
# NameError: name 'torch' is not defined

# %%
# !git clone https://github.com/NVlabs/stylegan2-ada-pytorch.git
# Out:
# fatal: destination path 'stylegan2-ada-pytorch' already exists and is not an empty directory.

# %%
# %cd /content/stylegan2-ada-pytorch
# Out:
# [WinError 2] The system cannot find the file specified: '/content/stylegan2-ada-pytorch'
# C:\Users\TI_ML

# %%
# %cd C:\Users\TI_ML\stylegan2-ada-pytorch
# Out:
# C:\Users\TI_ML\stylegan2-ada-pytorch

# %%
# %ls
# Out:
#  Volume in drive C is OS
#  Volume Serial Number is BE3B-B353
#
#  Directory of C:\Users\TI_ML\stylegan2-ada-pytorch
#
# 29-09-2023  14:19    <DIR>          .
# 29-09-2023  17:35    <DIR>          ..
# 29-09-2023  13:48    <DIR>          .github
# 29-09-2023  13:48                23 .gitignore
# 29-09-2023  14:19    <DIR>          __pycache__
# 29-09-2023  13:48             8,526 calc_metrics.py
# 29-09-2023  13:48            18,320 dataset_tool.py
# 29-09-2023  14:19    <DIR>          dnnlib
# 29-09-2023  13:48             1,234 docker_run.sh
# 29-09-2023  13:48               919 Dockerfile
# 29-09-2023  13:48    <DIR>          docs
# 29-09-2023  14:17    <DIR>          gan_test
# 29-09-2023  13:48             5,467 generate.py
# 29-09-2023  13:48            16,824 legacy.py
# 29-09-2023  13:48             4,518 LICENSE.txt
# 29-09-2023  14:19    <DIR>          metrics
# 29-09-2023  13:48             9,202 projector.py
# 29-09-2023  13:48            26,138 README.md
# ...

# %%
# %pip install torch==1.7.1+cu110 torchvision==0.8.2+cu110 -f https://download.pytorch.org/whl/torch_stable.html
# Out:
# ^C
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install torch==1.7.1
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install torch==1.7.1+cu110 torchvision==0.8.2+cu110 -f https://download.pytorch.org/whl/torch_stable.html
# Out:
# Looking in links: https://download.pytorch.org/whl/torch_stable.htmlNote: you may need to restart the kernel to use updated packages.
#
# ...

# %%
# %pip install click requests tqdm pyspng ninja imageio-ffmpeg==0.4.3
# Out:
# ...
#      ---------------------------------------- 97.9/97.9 kB 2.8 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 62.6/62.6 kB ? eta 0:00:00
# ...
#      ---------------------------------------- 78.3/78.3 kB 2.2 MB/s eta 0:00:00
# ...
#      -------------------------------------- 126.9/126.9 kB 3.8 MB/s eta 0:00:00
# ...
#   Using cached ninja-1.11.1-py2.py3-none-win_amd64.whl (313 kB)
# ...
#      ---------------------------------------- 22.6/22.6 MB 9.4 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 123.8/123.8 kB ? eta 0:00:00
# ...
#      ---------------------------------------- 94.7/94.7 kB 5.3 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
F:\Icon Detection\myvenv\datasets\gan_test
# Out:
#   File "C:\Users\TI_ML\AppData\Local\Temp\ipykernel_4268\408674538.py", line 1
#     F:\Icon Detection\myvenv\datasets\gan_test
#                                               ^
# SyntaxError: unexpected character after line continuation character

# %%
# !python dataset_tool.py --source=C:\Users\TI_ML\stylegan2-ada-pytorch\gan_test --dest=/content/dataset.zip --width=128 --height=128
# Out:
# python: can't open file 'dataset_tool.py': [Errno 2] No such file or directory

# %%
# !python train.py --outdir=/content/training-runs --data=/content/dataset.zip --dry-run
# Out:
# Training options:
# {
#   "num_gpus": 1,
#   "image_snapshot_ticks": 50,
#   "network_snapshot_ticks": 50,
#   "metrics": [
#     "fid50k_full"
#   ],
#   "random_seed": 0,
#   "training_set_kwargs": {
#     "class_name": "training.dataset.ImageFolderDataset",
#     "path": "/content/dataset.zip",
#     "use_labels": false,
#     "max_size": 16,
#     "xflip": false,
#     "resolution": 128
#   },
#   "data_loader_kwargs": {
#     "pin_memory": true,
#     "num_workers": 3,
#     "prefetch_factor": 2
#   },
#   "G_kwargs": {
#     "class_name": "training.networks.Generator",
#     "z_dim": 512,
#     "w_dim": 512,
#     "mapping_kwargs": {
#       "num_layers": 2
#     },
#     "synthesis_kwargs": {
#       "channel_base": 16384,
#       "channel_max": 512,
#       "num_fp16_res": 4,
#       "conv_clamp": 256
#     }
#   },
#   "D_kwargs": {
#     "class_name": "training.networks.Discriminator",
#     "block_kwargs": {},
#     "mapping_kwargs": {},
#     "epilogue_kwargs": {
# ...

# %%
# !pip install scipy
# Out:
# ...
#      --------------------------------------- 34.1/34.1 MB 14.9 MB/s eta 0:00:00
# ...

# %%
# !python train.py --outdir=/content/training-runs4 --data=/content/dataset.zip --dry-run
# Out:
# Training options:
# {
#   "num_gpus": 1,
#   "image_snapshot_ticks": 50,
#   "network_snapshot_ticks": 50,
#   "metrics": [
#     "fid50k_full"
#   ],
#   "random_seed": 0,
#   "training_set_kwargs": {
#     "class_name": "training.dataset.ImageFolderDataset",
#     "path": "/content/dataset.zip",
#     "use_labels": false,
#     "max_size": 16,
#     "xflip": false,
#     "resolution": 128
#   },
#   "data_loader_kwargs": {
#     "pin_memory": true,
#     "num_workers": 3,
#     "prefetch_factor": 2
#   },
#   "G_kwargs": {
#     "class_name": "training.networks.Generator",
#     "z_dim": 512,
#     "w_dim": 512,
#     "mapping_kwargs": {
#       "num_layers": 2
#     },
#     "synthesis_kwargs": {
#       "channel_base": 16384,
#       "channel_max": 512,
#       "num_fp16_res": 4,
#       "conv_clamp": 256
#     }
#   },
#   "D_kwargs": {
#     "class_name": "training.networks.Discriminator",
#     "block_kwargs": {},
#     "mapping_kwargs": {},
#     "epilogue_kwargs": {
# ...

# %%
# !python train.py --outdir=/content/training-runs4 --data=/content/dataset.zip
# Out:
# ^C

# %%
# !python generate.py --outdir=/content/out --trunc=1 --seeds=85,265,297,849 \
    --network=/content/training-runs1/00000-dataset-auto1/network-snapshot-000000.pkl
# Out:
# Loading networks from "/content/training-runs1/00000-dataset-auto1/network-snapshot-000000.pkl"...
# C:\Users\TI_ML\stylegan2-ada-pytorch\torch_utils\ops\bias_act.py:50: UserWarning: Failed to build CUDA kernels for bias_act. Falling back to slow reference implementation. Details:
#
# Traceback (most recent call last):
#   File "C:\Users\TI_ML\stylegan2-ada-pytorch\torch_utils\ops\bias_act.py", line 48, in _init
#     _plugin = custom_ops.get_plugin('bias_act_plugin', sources=sources, extra_cuda_cflags=['--use_fast_math'])
#   File "C:\Users\TI_ML\stylegan2-ada-pytorch\torch_utils\custom_ops.py", line 64, in get_plugin
#     raise RuntimeError(f'Could not find MSVC/GCC/CLANG installation on this computer. Check _find_compiler_bindir() in "{__file__}".')
# RuntimeError: Could not find MSVC/GCC/CLANG installation on this computer. Check _find_compiler_bindir() in "C:\Users\TI_ML\stylegan2-ada-pytorch\torch_utils\custom_ops.py".
#
# ...
