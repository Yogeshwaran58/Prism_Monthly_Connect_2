# %%
# %cd C:\Users\TI_ML\stylegan2-ada-pytorch
# Out:
# C:\Users\TI_ML\stylegan2-ada-pytorch

# %%
# !python dataset_tool.py --source=C:/content/gan_dataset --dest=C:/content/gan_dataset_256.zip --width=256 --height=256
# Out:
# ...
#  40%|####      | 4293/10604 [01:58<03:27, 30.35it/s]
# ...
# ...
# 100%|##########| 10604/10604 [04:58<00:00, 35.47it/s]

# %%
# !python train.py --outdir=C:/content/training-runs20 --data=C:/content/gan_dataset_256.zip --dry-run
# Out:
# Training options:
# {
#   "num_gpus": 1,
#   "image_snapshot_ticks": 50,
#   "network_snapshot_ticks": 50,
#   "metrics": [
#     "fid50k_full"
#   ],
#   "random_seed": 0,
#   "training_set_kwargs": {
#     "class_name": "training.dataset.ImageFolderDataset",
#     "path": "C:/content/gan_dataset_256.zip",
#     "use_labels": false,
#     "max_size": 10604,
#     "xflip": false,
#     "resolution": 256
#   },
#   "data_loader_kwargs": {
#     "pin_memory": true,
#     "num_workers": 3,
#     "prefetch_factor": 2
#   },
#   "G_kwargs": {
#     "class_name": "training.networks.Generator",
#     "z_dim": 512,
#     "w_dim": 512,
#     "mapping_kwargs": {
#       "num_layers": 2
#     },
#     "synthesis_kwargs": {
#       "channel_base": 16384,
#       "channel_max": 512,
#       "num_fp16_res": 4,
#       "conv_clamp": 256
#     }
#   },
#   "D_kwargs": {
#     "class_name": "training.networks.Discriminator",
#     "block_kwargs": {},
#     "mapping_kwargs": {},
# ...

# %%
# !python train.py --outdir=C:/content/training-runs20 --data=C:/content/gan_dataset_256.zip --kimg=5000 --batch=16 --aug=ada --target=0.6 --augpipe=bgcfnc
# Out:
# ^C

# %%
# !python train.py --outdir=C:/content/training-runs21 --data=C:/content/gan_dataset_256.zip --kimg=5000 --batch=16 --aug=ada --target=0.6 --augpipe=bgcfnc --resume=C:\content\training-runs20\00001-gan_dataset_256-auto1-kimg5000-batch16-ada-target0.6-bgcfnc\network-snapshot-001400.pkl
